# %% [markdown]
# <a href="https://colab.research.google.com/github/ia-nechaev/aqm2022/blob/main/Assignment_ch9_10_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment
#
# Each of the following doctors have a burning research question, they need help with. Try to help as many as you can.
#
# Your job is:
#
# 1. to turn their questions into hypotheses
# 2. define the variables (continuous or categorical/discrete)
# 3. determine which statistical model is the best tool to answer the hypothesis
# 4. run the model on the dataset
# 5. interpret the results
# 6. write-up the results for the specific doctor and submit them

# %% [markdown]
# ```
# mydata=pd.read_csv('https://raw.githubusercontent.com/ia-nechaev/aqm2022/main/data/coffee_study.csv')
# ```

# %% [markdown]
# #Dr. Stephen Strange
#
# "People think in terms of good and evil, when really time is the true enemy of us all. We don't get to choose our time"
#
# "But still I ask you, do we enjoy things more deeply with time? Do we love our coffee break more after we have passed through time?
#
# -- Dr. Strange
#
# (Paired t-test)
#
# Use stud_coffee_breaks, prof_coffee_breaks variables for comparison.

# %% [markdown]
# ![Dr. strange.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# #Dr. Seuss
# "You're off to Great Places! Today is your day! Your mountain is waiting, So... get on your way!"
#
# "But before you go, let me ask you a thing. Is coffee more darling of the sleeply or the man on the go?"
#
# ― Dr. Seuss
#
# (Independent t-test)
#
# Use sleepy_coffee_value and on_the_go_coffee_value.

# %% [markdown]
# ![Dr.seuss.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# #Dr. No
#
# "All the greatest men are maniacs. They are possessed by a mania which drives them forward towards their goal. The great scientists, the philosophers, the religious leaders - all maniacs. What else but a blind singleness of purpose could have given focus to their genius, would have kept them in the groove of their purpose?"
#
# "Hmmm, unless, my dear Mister Bond, they are just obsessive coffee drinkers beyond mean, convention and expectation?"
#
# -- Dr. No
#
# (one-sample t-test)
#
# Use coffee_consumption_scientists_year. On average people consume 1131 cups per year.

# %% [markdown]
# ![Dr. No.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# #Dr. Dumbledore
#
# "We must all face the choice between what is right, and what is easy. It is our choices, Harry, that show what we truly are, far more than our abilities".
#
# "But when we choose to have a cup of coffee, we expect to be a choice. But maybe not. Even our smallest of choices, like a cappuccino, espresso, mocha, latte or flat white, may not the same choice at all?"
#
# -- Dr. Dumbledore
#
#
# (Chi-square test of homegenenuity)
#
# Use coffee_type_stud and coffee_type_prof.
#
#
#
# ```
# import pandas as pd
# coffee_type_exp={'coffee_type':['cappuccino','espresso', 'americano', 'latte', 'others'],'ratio':[0.45,0.04,0.1,0.2,0.21]}
# df = pd.DataFrame.from_dict(coffee_type_exp)
#
# df['stud']=pd.DataFrame(coffee_type_stud).value_counts().tolist()
# df['prof']=pd.DataFrame(coffee_type_prof).value_counts().tolist()
#
# ```
# Some minor changes might be needed to the code above.

# %% [markdown]
# ![Dr. Dumbledore.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# #Dr. Indiana Jones
#
# “I mean that for nearly three thousand years man has been searching for the lost Ark. It’s not something to be taken lightly. No one knows its secrets. It’s like nothing you’ve ever gone after before.”
#
# "Like a cup of coffee you have never had, with a friend, you've never met." How would you ever determine if it was worth having at all?"
#
# --Dr. Jones
#
# (Chi-square Goodness-of-fit test)
#
# Choose coffee_type_stud or coffee_type_prof for this test. For real population sample use ratio variable from the previous example.
#
# ```
# df['quant_100']=list(np.multiply(coffee_type_exp['ratio'],100))
#
# ```

# %% [markdown]
# ![Dr. Indiana.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# #Dr. John Watson
#
# "Much of what I tell you is no doubt quite irrelevant, but I still feel that it is best that I should let you have all the facts and leave you to select for yourself those which will be of most service to you in helping you to your conclusions. So I do not trouble you with my theories, for you asked me to furnish you only with facts.
#
# "But still I will trouble you with one theory. The cheaters drink coffee with milk, thiefs drink it with milk and sugar, while murders drink it black. Could it be likely, you think, Sherlock?"
#
# --Dr. Watson
#
# (Chi-square test of independence)
#
# Use coffee_cheater, coffee_thief and coffee_murder. Define new data frame and count the variables in the colummns.
#
#
#
# ```
# dictionary={'type':['','', '']}
# df = pd.DataFrame.from_dict(dictionary)
#
# *.value_counts().tolist()
#
# ```

# %% [markdown]
# ![Dr. Watson.jpeg](data:image/jpeg;base64,...)
