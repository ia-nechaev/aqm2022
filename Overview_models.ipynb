# %% [markdown]
# **Decision tree for linear models**

# %% [markdown]
# ![andyfield-models.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# **Our decision tree for linear models (what we're mainly covering at HA3)**

# %% [markdown]
# ![Models_HA3 (2).png](data:image/png;base64,...)
