# %% [markdown]
# #Models for testing relationships in categorical response data

# %% [markdown]
# #1. Chi-square goodness-of-fit
#
# A statistical hypothesis that is used to determine if a sample (categorical variable) is representative of a theoretical distribution. A theoretical distribution is our idea about how should data act.

# %% [markdown]
# **1. Stating the Hypotheses:**
#
# $H_0:$
#
# $H_a:$

# %% [markdown]
# **Example:**
#
# Each day, the teacher greets students. He greets them "good morning", "good afternoon", and "good evening" on their way to lectures.
#
# Despite lectures being equally distributed throughout the day, he suspects that he is greeting more students on campus in the afternoon, than the morning and evening.
#
# $H_0: p_{morning} = p_{afternoon} = p_{evening}$
#
# $H_a$: At least one $p_i$ is not equal
#
# ($P_i$ = proportion of each greeting)

# %% [markdown]
# **3. Checking conditions for inference**
#
# *   Random sample
# *   Large count
# * Independent choices

# %% [markdown]
# **4. Setting the significance level**

# %% [markdown]
# **5. Checking the data**
#
# *   sample size
# *normally distributed
# * outliers

# %% [markdown]
# **6. Calculating a chi-statistics**
#
# Finding the difference between the expected choices and the actual choices.
#
# $$\chi_2 =(O_i-E_i)^2/E_i$$
#
# **Example:**
#
# "Are more students greeting the teacher in the afternoon?"
#
# He sampled 3 random days out of the semester equal to, $N = 75$ greetings, and recorded his rate of the correct greetings (i.e., good morning, good afternoon, good evening). He did not record greetings like "hey dude", "what's up, doc", "later...".
#
# **Expected number (E)**: He expects to get "good morning" = 25,  "good afternoon" = 25, "good evening" = 25.
#
# **Observed number (O):** He actually gets "good morning" = 20, "good afternoon" = 35, "good evening" = 20
#
# $$\chi_2 = \frac{(20-25)^2}{25}+ \frac{(35-25)^2}{25}+ \frac{(20-25)^2}{25} $$
#
# $$\chi_2 = 1 + 4 + 1 = 6$$

# %% [markdown]
# ![Screenshot 2022-10-27 at 11.32.51.png](data:image/png;base64,...)

# %% [markdown]
# **7. Check the probability for getting this chi-square statistic using a $chi$-distribution critical values table.**
#
# Remember: the degrees of freedom for this test is the number of groups $n-1$
#
# **Example:**
#
# **P-value**
#
# We can use a $\chi$ critical values table to determine the p-value.
#
# So, in the example, degrees of freedom: $3-1 = 2$  and we check to see the probability level for a chi-value of 6 or greater and see p > 0.10 on a chi-square distribution.
#
# Since the p-value is higher than the significance level set $\alpha = 0.05$, then we'll fail to reject the $H_0$

# %% [markdown]
# **8. Alternatively, calculate a test statistic using python.**

# %% [markdown]
# #2. Chi-square test of homogeneity

# %% [markdown]
# **Gotta finish this one...**

# %% [markdown]
# # 3. Chi-square test of independence
#
# A statistical hypothesis test used to determine whether two categorical or nominal variables are related or not.

# %% [markdown]
# **1. Stating the Hypotheses:**
#
# $H_0$:
#
# $H_a$:

# %% [markdown]
# **Example:**
#
# Each day, the Head of the Business School greets students on their way to lectures. However, some students don't greet him. He wonders if the rate of student's greetings are dependent of their majors.
#
# $H_0$: students' decision to greet is independent of their major
#
# $H_a$:students' decision to greet is dependent of their major

# %% [markdown]
# **2. Set significance level**
#
# Decide the alpha value. Specifically, the risk you are willing to take on drawing the wrong conclusion.
#
# For example, $\alpha = 0.05$ means the risk of stating that two variables are independent when they are not.

# %% [markdown]
# **3. Conditions of inference**
#
# These assumptions needs to be met for the test to be appropriate.
#
# *   A simple random sample
# *   Two variables: both are categorical
# *   More than five expected values for each combination of the two variables. To confirm this, we need to know the total counts for each type of combination and the total counts.

# %% [markdown]
# **4. Checking the assumption of expected values in each category**
#
# Example:

# %% [markdown]
# ![Screenshot 2022-10-29 at 07.11.21.png](data:image/png;base64,...)

# %% [markdown]
# Calculating the expected count for each major - greeting combination needs to exceed 5 to meet the assumptions.
#
# $Business \:data \: science_{expected}: \frac{25*100}{362} = 6.91$
#
# $Business \:data \: science_{expected}: \frac{25*81}{362} = 5.59$
#
# Given these are the smallest counts, we can conclude that the expected count assumption is met.

# %% [markdown]
# **5. Calculating the chi_square test statistics of independence**
#
# Finding the difference between the expected choices and the actual choices.
#
# $$\chi_2 =\sum \frac{(O_ij-E_ij)^2}{E_ij}$$

# %% [markdown]
# ![Screenshot 2022-10-29 at 07.20.50.png](data:image/png;base64,...)

# %% [markdown]
# **Example:**
#
# "Does the rate of student's greetings independent of their majors?"
#
#
# $$\chi_2 = \frac{(12-10)^2}{10}+ \frac{(13-15)^2}{15}+ \frac{(25-25)^2}{25} + \frac{(20-20)^2}{20} + \frac{(22-30)^2}{30} +  \frac{(24-16)^2}{16}\frac{(18-15)^2}{15} + \frac{(7-10)^2}{10} + \frac{(25-20)^2}{20} + \frac{(15-20)^2}{20}$$
#
# $$\chi_2 = 0.4 + 0.27 + 4 + 4 + 0.6 + 0.9 + 0.25 + 0.25$$
#
# $$\chi_2 = 10.67 $$

# %% [markdown]
# **6. Check the probability for getting this chi-square statistic using a $chi$-distribution critical values table.**
#
# Degrees of freedom $(df) = (r-1) * (c-1)$
#
# In the example, df = (5-1) * (2-1) = 5
#
# The chi-square value with alpha = 0.05 and 5 degrees of freedom is 11.05, since 10.67 is less than 11.05, we accept the idea that greetings and majors are independent. We conclude that there is no relationship between major and decision to greet.

# %% [markdown]
# **7. Alternatively, calculate a test statistic using python.**
